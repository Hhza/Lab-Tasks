# %%
import numpy as np
import random

# %%
#Task 1

v1=np.random.randint(2,10,size=(1,2))
v1[0]
# Out:
# array([7, 9])

# %%
#Task 2
t=[]
t.append(1)
t.append((-1 * (v1[0][0]*1))/v1[0][1])
print(t)
np.dot(v1[0],t)
# Out:
# [1, -0.7777777777777778]
# 0.0

# %%
np.linalg.norm(v1)
# Out:
# 11.40175425099138

# %%
#Task 3
temp=v1/np.linalg.norm(v1)
temp1=np.dot(v1,t)/np.linalg.norm(v1)
temp2=temp1*temp
temp2
# Out:
# array([[0., 0.]])

# %%
#Task 3

temp=v1/np.linalg.norm(t)
temp1=np.dot(t,v1[0])/np.linalg.norm(t)
temp2=temp1*temp
temp2
# Out:
# array([[0., 0.]])

# %% [markdown]
# # Task 4
# ### We can not find the intitial vector from projection as projection is zero

# %%
#Task 5
v1=np.random.randint(2,10,size=(1,2))
v2=np.random.randint(2,10,size=(1,2))
#projection of v1 on v2
temp=v1/np.linalg.norm(v1)
temp1=np.dot(v1[0],v2[0])/np.linalg.norm(v1)
temp2=temp1*temp
print(temp2)
#projection of v2 on v1
temp=v2/np.linalg.norm(v2)
temp1=np.dot(v2[0],v1[0])/np.linalg.norm(v2)
temp2=temp1*temp
print(temp2)
# Out:
# [[2.89655172 7.24137931]]
# [[3.5 3.5]]

# %%
from sklearn import datasets
from sklearn.decomposition import PCA

# import some data to play with
iris = datasets.load_iris()
X = iris.data  # we only take the first two features.
y = iris.target
from numpy.linalg import eig
aa=np.dot(X,X.T)
x,y=eig(aa)
print(x[0])
print(y[0])
# Out:
# (9208.305070314853+0j)
# [ 6.16168450e-02+0.j         -1.29611444e-01+0.j
#  -2.13859674e-03+0.j         -1.63819140e-03+0.j
#   7.21340090e-02-0.05708074j  7.21340090e-02+0.05708074j
#  -6.94947106e-02-0.01016376j -6.94947106e-02+0.01016376j
#  -1.95898529e-02-0.01885361j -1.95898529e-02+0.01885361j
#  -3.68698380e-02+0.j         -5.69883035e-02+0.j
#   1.90796199e-02+0.01865112j  1.90796199e-02-0.01865112j
#   4.66233900e-02-0.05581612j  4.66233900e-02+0.05581612j
#  -1.81596605e-02-0.0116075j  -1.81596605e-02+0.0116075j
#   6.61269340e-02+0.00559094j  6.61269340e-02-0.00559094j
#  -1.15716359e-02+0.01430789j -1.15716359e-02-0.01430789j
#   4.33822047e-02+0.00292608j  4.33822047e-02-0.00292608j
#  -5.05981292e-02-0.00818666j -5.05981292e-02+0.00818666j
#  -5.63824827e-02-0.03045246j -5.63824827e-02+0.03045246j
#   3.25584160e-02-0.1134158j   3.25584160e-02+0.1134158j
#  -2.47849535e-03+0.00395049j -2.47849535e-03-0.00395049j
# ...

# %%
df = np.mean(X , axis=0)
temps=X-df
import pandas as pd
df1=pd.DataFrame(temps)
df1.columns=[	"sepal length (cm)"	,"sepal width (cm)"	,"petal length (cm)",	"petal width (cm)"]
df1
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0            -0.743333          0.442667             -2.358         -0.999333
# 1            -0.943333         -0.057333             -2.358         -0.999333
# 2            -1.143333          0.142667             -2.458         -0.999333
# 3            -1.243333          0.042667             -2.258         -0.999333
# 4            -0.843333          0.542667             -2.358         -0.999333
# ..                 ...               ...                ...               ...
# 145           0.856667         -0.057333              1.442          1.100667
# 146           0.456667         -0.557333              1.242          0.700667
# 147           0.656667         -0.057333              1.442          0.800667
# 148           0.356667          0.342667              1.642          1.100667
# 149           0.056667         -0.057333              1.342          0.600667
#
# [150 rows x 4 columns]

# %%
df2=pd.read_csv("/content/ECG200_TRAIN (1).csv",delimiter="  ")
me=np.mean(df2.values,axis=0)
temps=df2.values-me
temps
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)
# array([[ 0.60606061, -0.56287534, -0.62637147, ..., -0.24174343,
#         -1.44254023, -0.3802724 ],
#        [-1.39393939, -0.39387608, -1.18784079, ...,  0.47024815,
#          0.64057621,  0.36709903],
#        [-1.39393939,  0.45835186,  0.64486093, ...,  0.97834931,
#          0.62294075,  0.5592918 ],
#        ...,
#        [-1.39393939, -0.51284532, -0.97562329, ..., -0.39860609,
#         -0.1350432 ,  0.17104543],
#        [ 0.60606061, -0.53102196, -0.39263067, ..., -0.12755002,
#          0.01591168,  0.27946052],
#        [ 0.60606061, -0.63739806, -0.65498581, ..., -0.34528895,
#         -0.35591375, -0.4282996 ]])

# %%
import pandas as pd
df3=pd.DataFrame(temps)

# %%
df3
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.606061 -0.562875 -0.626371 -1.684678 -1.889607 -1.519094 -1.021311
# 1  -1.393939 -0.393876 -1.187841 -1.681978 -1.069763  0.132479  1.012649
# 2  -1.393939  0.458352  0.644861 -0.292309 -0.527055  0.403337  0.555934
# 3   0.606061 -0.061865 -0.679014  0.583781  1.322214  0.572449 -0.226288
# 4   0.606061 -0.305790 -0.150181  0.462698 -0.833982 -0.092276 -0.272633
# ..       ...       ...       ...       ...       ...       ...       ...
# 94  0.606061 -0.129245 -0.554852 -1.009683 -0.337381  0.995691  1.499744
# 95 -1.393939  1.978495  1.277664 -0.044068  0.102299 -0.028727 -0.716992
# 96 -1.393939 -0.512845 -0.975623 -1.079340 -0.197545  0.713755  0.994432
# 97  0.606061 -0.531022 -0.392631 -0.106029  0.571640  0.124998 -0.848075
# 98  0.606061 -0.637398 -0.654986  0.128886  1.306824  0.622767 -0.249593
#
#           7         8         9   ...        87        88        89        90  \
# ...
